# %%
# ------------------------------------------------------------------
# Load Libraries & Data
# ------------------------------------------------------------------
import pandas as pd
import numpy as np
import os
import re
import pycm
print(os.getcwd())
# Out:
# c:\Users\stdt\ETH Zurich\PhD Veronika - 07_Master Thesis Natalie\10_hcm_code\code
